# %%
import subprocess
import os
import time

def send_email_via_apple_mail(to, subject, body_text, attachment_path=None):
    safe_subject = subject.replace('"', '\\"')
    safe_body = body_text.replace('"', '\\"').replace('\n', '\\n')

    applescript = f'''
    tell application "Mail"
        set newMessage to make new outgoing message with properties {{subject:"{safe_subject}", content:"{safe_body}", visible:false}}
        tell newMessage
            make new to recipient at end of to recipients with properties {{address:"{to}"}}
    '''

    if attachment_path:
        abs_path = os.path.abspath(attachment_path)
        applescript += f'''
            try
                set theAttachment to POSIX file "{abs_path}" as alias
                make new attachment with properties {{file name:theAttachment}} at after the last paragraph
            on error errMsg
                display dialog "Attachment failed: " & errMsg
            end try
        '''

    applescript += '''
            send
        end tell
    end tell
    '''

    subprocess.run(["osascript", "-e", applescript])

# %%
import time

subject = "Seeking Graduate Research Assistant Opportunity"

body = """Hello Professor,

I hope you are doing well. I am Prajeeth Channa, recently admitted to the MS-CS program for Spring '25.

I'm writing to express my interest in any Graduate or Student Assistantship opportunities you may have. I've attached my resume.

Thank you for your time.

Best Regards,
Prajeeth Channa
"""

resume_path = "/Users/jithu/Desktop/ML/Prajeeth_Resume.pdf"

for recipient in nursing_project_funding_email:
    send_email_via_apple_mail(recipient, subject, body, attachment_path=resume_path)
    print(f"✅ Sent to {recipient}")
    time.sleep(5)  # 5-second delay
# Out:
# true
# ✅ Sent to daycock@gsu.edu
# true
# ✅ Sent to sbhattacharjya@gsu.edu
# true
# ✅ Sent to kbrandenberger1@gsu.edu
# true
# ✅ Sent to ebuchman@gsu.edu
# true
# ✅ Sent to kmanning2@gsu.edu
# true
# ✅ Sent to mchen13@gsu.edu
# true
# ✅ Sent to ychen102@gsu.edu
# true
# ✅ Sent to ypchen@gsu.edu
# true
# ✅ Sent to rferesin@gsu.edu
# true
# ✅ Sent to dgardenhire@gsu.edu
# true
# ✅ Sent to sgalen@gsu.edu
# true
# ✅ Sent to khsieh5@gsu.edu
# true
# ✅ Sent to ykang18@gsu.edu
# true
# ✅ Sent to kkirkendoll@gsu.edu
# true
# ✅ Sent to plawrence4@gsu.edu
# true
# ✅ Sent to jlee242@gsu.edu
# true
# ✅ Sent to jstern@gsu.edu
# true
# ✅ Sent to alorio@gsu.edu
# true
# ✅ Sent to kmayfield@gsu.edu
# true
# ✅ Sent to anucci@gsu.edu
# true
# ✅ Sent to gpriest@gsu.edu
# true
# ✅ Sent to vrowe4@gsu.edu
# true
# ✅ Sent to jsanford1@gsu.edu
# true
# ✅ Sent to nshaikh2@gsu.edu
# true
# ✅ Sent to tsims8@gsu.edu
# true
# ✅ Sent to ltsai@gsu.edu

# %%
nursing_project_funding_email = [
    "daycock@gsu.edu",
    "sbhattacharjya@gsu.edu",
    "kbrandenberger1@gsu.edu",
    "ebuchman@gsu.edu",
    "kmanning2@gsu.edu",
    "mchen13@gsu.edu",
    "ychen102@gsu.edu",
    "ypchen@gsu.edu",
    "rferesin@gsu.edu",
